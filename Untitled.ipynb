# %%
# !ls
# !ls house-prices-advanced-regression-techniques
# Out:
# house-prices-advanced-regression-techniques	 Untitled.ipynb
# house-prices-advanced-regression-techniques.zip
# data_description.txt  sample_submission.csv  test.csv  train.csv

# %%
import pandas as pd 

df_test = pd.read_csv("house-prices-advanced-regression-techniques/test.csv")
df_train = pd.read_csv("house-prices-advanced-regression-techniques/train.csv")
df_ss = pd.read_csv("house-prices-advanced-regression-techniques/sample_submission.csv")

# %%
import warnings
warnings.filterwarnings('ignore')


# %matplotlib inline
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt
import scipy.stats as stats
import sklearn.linear_model as linear_model
import seaborn as sns
from sklearn.model_selection import KFold
from IPython.display import HTML, display
from sklearn.manifold import TSNE
from sklearn.cluster import KMeans
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler

pd.options.display.max_rows = 1000
pd.options.display.max_columns = 20

train = pd.read_csv('house-prices-advanced-regression-techniques/train.csv')
test = pd.read_csv('house-prices-advanced-regression-techniques/train.csv')

quantitative = [f for f in train.columns if train.dtypes[f] != 'object']
quantitative.remove('SalePrice')
quantitative.remove('Id')
qualitative = [f for f in train.columns if train.dtypes[f] == 'object']


train
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0        1          60       RL         65.0     8450   Pave   NaN      Reg
# 1        2          20       RL         80.0     9600   Pave   NaN      Reg
# 2        3          60       RL         68.0    11250   Pave   NaN      IR1
# 3        4          70       RL         60.0     9550   Pave   NaN      IR1
# 4        5          60       RL         84.0    14260   Pave   NaN      IR1
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1455  1456          60       RL         62.0     7917   Pave   NaN      Reg
# 1456  1457          20       RL         85.0    13175   Pave   NaN      Reg
# 1457  1458          70       RL         66.0     9042   Pave   NaN      Reg
# 1458  1459          20       RL         68.0     9717   Pave   NaN      Reg
# 1459  1460          20       RL         75.0     9937   Pave   NaN      Reg
#
# ...

# %%
print(quantitative)
# Out:
# ['MSSubClass', 'LotFrontage', 'LotArea', 'OverallQual', 'OverallCond', 'YearBuilt', 'YearRemodAdd', 'MasVnrArea', 'BsmtFinSF1', 'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', '1stFlrSF', '2ndFlrSF', 'LowQualFinSF', 'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath', 'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr', 'TotRmsAbvGrd', 'Fireplaces', 'GarageYrBlt', 'GarageCars', 'GarageArea', 'WoodDeckSF', 'OpenPorchSF', 'EnclosedPorch', '3SsnPorch', 'ScreenPorch', 'PoolArea', 'MiscVal', 'MoSold', 'YrSold']

# %%
print(qualitative)
# Out:
# ['MSZoning', 'Street', 'Alley', 'LotShape', 'LandContour', 'Utilities', 'LotConfig', 'LandSlope', 'Neighborhood', 'Condition1', 'Condition2', 'BldgType', 'HouseStyle', 'RoofStyle', 'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrType', 'ExterQual', 'ExterCond', 'Foundation', 'BsmtQual', 'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinType2', 'Heating', 'HeatingQC', 'CentralAir', 'Electrical', 'KitchenQual', 'Functional', 'FireplaceQu', 'GarageType', 'GarageFinish', 'GarageQual', 'GarageCond', 'PavedDrive', 'PoolQC', 'Fence', 'MiscFeature', 'SaleType', 'SaleCondition']

# %%
# количество null в столбцах. В некоторых пропущено более половины данных
missing = train.isnull().sum()
missing = missing[missing > 0]
missing.sort_values(inplace=True)
missing.plot.bar()
# Out:
# <AxesSubplot:>

# %%
# сравним данные с распределениями 

import scipy.stats as st
y = train['SalePrice']


plt.figure(2); plt.title('Normal')
sns.distplot(y, kde=False, fit=st.norm)
plt.figure(3); plt.title('Log Normal')
sns.distplot(y, kde=False, fit=st.lognorm)

#plt.figure(4); plt.title('Normal')
#sns.distplot(np.log(y), kde=False, fit=st.norm).set(xlabel='log SalePrice')

plt.figure(1); plt.title('Johnson SU')
sns.distplot(y, kde=False, fit=st.johnsonsu)
a, b, c, d = st.johnsonsu.fit(y)
st.johnsonsu(a, b).pdf
import matplotlib.pyplot as plt 

plt.figure()
sns.distplot(y, kde=False, norm_hist=True)
plt.plot(np.linspace(0, 200000, 100), st.johnsonsu(a=a, b=b, loc=c, scale=d).pdf(np.linspace(0, 200000, 100)))





# для применения критерия Фишера распределение должно быть близко к нормальному. Здесь оно ближе к логнормальному.

# %%
# Проведем тест на нормальность для численных признаков, используя критерий Шапиро с уровнем значимости 0.01
test_normality = lambda x: stats.shapiro(x)[1] < 0.001
normal = pd.DataFrame(train[quantitative])
normal = normal.apply(test_normality)
#print(not normal.any())

def to_normal(x, a, b):
    sqrt = np.sqrt(x ** 2 + 1)
    val = 2 * np.log(sqrt) / np.log(b) + a ** 2 + b ** 2 * np.log(x + sqrt) ** 2 + 2 * a * b * np.log(x + sqrt)
    return np.sqrt(val)
    

y_norm = to_normal((y + c) / d, a, b)
    
sns.distplot(y_norm, kde=False, norm_hist=True, fit=st.t)

stats.shapiro(y_norm)

#print(test_normality(stats.norm.rvs(size=100)))

#print(test_normality(y_norm))

#print(test_normality(np.log(y)))

#print(stats.shapiro(y))

#print(stats.shapiro(np.log(y)))
# Out:
# ShapiroResult(statistic=0.9724029302597046, pvalue=4.1862729357647994e-16)

# %%
for c in qualitative:
    train[c] = train[c].astype('category')
    if train[c].isnull().any():
        train[c] = train[c].cat.add_categories(['MISSING'])
        train[c] = train[c].fillna('MISSING')

def boxplot(x, y, **kwargs):
    sns.boxplot(x=x, y=y)
    x=plt.xticks(rotation=90)
f = pd.melt(train, id_vars=['SalePrice'], value_vars=qualitative)
g = sns.FacetGrid(f, col="variable",  col_wrap=2, sharex=False, sharey=False, size=5)
g = g.map(boxplot, "value", "SalePrice")

# %%
def anova(frame):
    frame['logSalePrice'] = np.log(frame['SalePrice'])
    anv = pd.DataFrame()
    anv['feature'] = qualitative
    pvals = []
    for c in qualitative:
        samples = []
        for cls in frame[c].unique():
            s = frame[frame[c] == cls]['logSalePrice'].values
            samples.append(s)
        pval = stats.f_oneway(*samples)[1]
        pvals.append(pval)
    anv['pval'] = pvals
    return anv.sort_values('pval')

a = anova(train)
a['disparity'] = np.log(1./a['pval'].values)
#sns.barplot(data=a, x='feature', y='pval')
plt.title(r'$ln(1/pvalue)$', fontsize='large')
sns.barplot(data=a, x='feature', y='disparity')
x=plt.xticks(rotation=90)


a.feature[:5]
# Out:
# 8     Neighborhood
# 18       ExterQual
# 21        BsmtQual
# 30     KitchenQual
# 34    GarageFinish
# Name: feature, dtype: object

# %%
for c in a.feature[:5]:
    train[c] = train[c].astype('category')
    if train[c].isnull().any():
        train[c] = train[c].cat.add_categories(['MISSING'])
        train[c] = train[c].fillna('MISSING')
        
def boxplot(x, y, **kwargs):
    sns.boxplot(x=x, y=y)
    x=plt.xticks(rotation=90)
    
def histplot(x, y, **kwargs):
    sns.histplot(x=x, y=y)
    x=plt.xticks(rotation=90)


f = pd.melt(train, id_vars=['logSalePrice'], value_vars=a.feature[:3])
g = sns.FacetGrid(f, col="variable",  col_wrap=2, sharex=False, sharey=False, size=5)
g = g.map(boxplot, "value", "logSalePrice")

#g = sns.FacetGrid(f, col="variable",  col_wrap=2, sharex=False, sharey=False, size=5)

# %%
sns.histplot
# Out:
# <function seaborn.distributions.histplot(data=None, *, x=None, y=None, hue=None, weights=None, stat='count', bins='auto', binwidth=None, binrange=None, discrete=None, cumulative=False, common_bins=True, common_norm=True, multiple='layer', element='bars', fill=True, shrink=1, kde=False, kde_kws=None, line_kws=None, thresh=0, pthresh=None, pmax=None, cbar=False, cbar_ax=None, cbar_kws=None, palette=None, hue_order=None, hue_norm=None, color=None, log_scale=None, legend=True, ax=None, **kwargs)>

# %%
def encode(frame, feature):
    ordering = pd.DataFrame()
    ordering['val'] = frame[feature].unique()
    ordering.index = ordering.val
    ordering['spmean'] = frame[[feature, 'SalePrice']].groupby(feature).mean()['SalePrice']
    ordering = ordering.sort_values('spmean')
    ordering['ordering'] = range(1, ordering.shape[0]+1)
    ordering = ordering['ordering'].to_dict()
    
    for cat, o in ordering.items():
        frame.loc[frame[feature] == cat, feature+'_E'] = o
    
qual_encoded = []
for q in qualitative:  
    encode(train, q)
    qual_encoded.append(q+'_E')
print(qual_encoded)
# Out:
# ['MSZoning_E', 'Street_E', 'Alley_E', 'LotShape_E', 'LandContour_E', 'Utilities_E', 'LotConfig_E', 'LandSlope_E', 'Neighborhood_E', 'Condition1_E', 'Condition2_E', 'BldgType_E', 'HouseStyle_E', 'RoofStyle_E', 'RoofMatl_E', 'Exterior1st_E', 'Exterior2nd_E', 'MasVnrType_E', 'ExterQual_E', 'ExterCond_E', 'Foundation_E', 'BsmtQual_E', 'BsmtCond_E', 'BsmtExposure_E', 'BsmtFinType1_E', 'BsmtFinType2_E', 'Heating_E', 'HeatingQC_E', 'CentralAir_E', 'Electrical_E', 'KitchenQual_E', 'Functional_E', 'FireplaceQu_E', 'GarageType_E', 'GarageFinish_E', 'GarageQual_E', 'GarageCond_E', 'PavedDrive_E', 'PoolQC_E', 'Fence_E', 'MiscFeature_E', 'SaleType_E', 'SaleCondition_E']

# %%
train
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street    Alley  \
# 0        1          60       RL         65.0     8450   Pave  MISSING
# 1        2          20       RL         80.0     9600   Pave  MISSING
# 2        3          60       RL         68.0    11250   Pave  MISSING
# 3        4          70       RL         60.0     9550   Pave  MISSING
# 4        5          60       RL         84.0    14260   Pave  MISSING
# ...    ...         ...      ...          ...      ...    ...      ...
# 1455  1456          60       RL         62.0     7917   Pave  MISSING
# 1456  1457          20       RL         85.0    13175   Pave  MISSING
# 1457  1458          70       RL         66.0     9042   Pave  MISSING
# 1458  1459          20       RL         68.0     9717   Pave  MISSING
# 1459  1460          20       RL         75.0     9937   Pave  MISSING
#
#      LotShape LandContour Utilities  ... GarageType_E GarageFinish_E  \
# ...
